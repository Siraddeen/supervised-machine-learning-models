# %% [markdown]
# In this project, we will be using the Breast Cancer Wisconsin (Diagnostic) Data Set from the UCI Repository.
# We will be training a K-Nearest Neighbor (KNN) algorithm to predict whether a cell is Benign or Malignant
# Description — Sample data is available at https://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+(original)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#! pip install pyforest
from pyforest import *
#lazy_imports()

# %%
df = pd.read_csv('wisc_bc_data_knn.csv')

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
# here y column is our targeted variable contain b- benign(not cancer) & m- Malignant (cancer)

# %%
df['diagnosis']
# Out:
# 0      B
# 1      B
# 2      B
# 3      B
# 4      B
#       ..
# 564    B
# 565    B
# 566    M
# 567    B
# 568    M
# Name: diagnosis, Length: 569, dtype: object

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# here M & B are balanced i.e.. 357,212   are not too distant values

# %%
df.shape
# Out:
# (569, 32)

# %%
df.dtypes
# Out:
# id                     int64
# diagnosis             object
# radius_mean          float64
# texture_mean         float64
# perimeter_mean       float64
# area_mean            float64
# smoothness_mean      float64
# compactness_mean     float64
# concavity_mean       float64
# points_mean          float64
# symmetry_mean        float64
# dimension_mean       float64
# radius_se            float64
# texture_se           float64
# perimeter_se         float64
# area_se              float64
# smoothness_se        float64
# compactness_se       float64
# concavity_se         float64
# points_se            float64
# symmetry_se          float64
# dimension_se         float64
# radius_worst         float64
# texture_worst        float64
# perimeter_worst      float64
# area_worst           float64
# smoothness_worst     float64
# compactness_worst    float64
# concavity_worst      float64
# points_worst         float64
# symmetry_worst       float64
# dimension_worst      float64
# ...

# %%
# now let us change diagnosis from       object        to       categorial

df['diagnosis']= df['diagnosis'].astype('category')

# %%
df.dtypes
# Out:
# id                      int64
# diagnosis            category
# radius_mean           float64
# texture_mean          float64
# perimeter_mean        float64
# area_mean             float64
# smoothness_mean       float64
# compactness_mean      float64
# concavity_mean        float64
# points_mean           float64
# symmetry_mean         float64
# dimension_mean        float64
# radius_se             float64
# texture_se            float64
# perimeter_se          float64
# area_se               float64
# smoothness_se         float64
# compactness_se        float64
# concavity_se          float64
# points_se             float64
# symmetry_se           float64
# dimension_se          float64
# radius_worst          float64
# texture_worst         float64
# perimeter_worst       float64
# area_worst            float64
# smoothness_worst      float64
# compactness_worst     float64
# concavity_worst       float64
# points_worst          float64
# symmetry_worst        float64
# ...

# %%
#Droping unneccessary column
df= df.drop('id',axis=1)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        12.32         12.39           78.85      464.1
# 1         B        10.60         18.95           69.28      346.4
# 2         B        11.04         16.83           70.92      373.2
# 3         B        11.28         13.39           73.00      384.8
# 4         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1959  ...         13.50          15.64            86.97
# ...

# %% [markdown]
# Now seperate columns as targeted value & usable values

# %%
X = df.drop(labels = 'diagnosis',axis = 1)   # independent vairables
y= df['diagnosis']                           # dependent variables                       
#we did this to prevent data leak

# %% [markdown]
# ##### if you clearly see in df columns one columns data is eigther too large or too small if we let our model feed on this data then it goona not perform well so let us standartise it first

# %%
# let's Standardize our data
# one more thing you have to do this Standardization one to independent variables only (x) not on targetted varriable(y)

from scipy.stats import zscore

XScaled = X.apply(zscore)           # z= (x-xbar)/std              xbar = mean

# %%
XScaled.describe()
# Out:
#         radius_mean  texture_mean  perimeter_mean     area_mean  \
# count  5.690000e+02  5.690000e+02    5.690000e+02  5.690000e+02
# mean  -1.287781e-16 -7.373520e-16   -1.303390e-16 -2.239958e-16
# std    1.000880e+00  1.000880e+00    1.000880e+00  1.000880e+00
# min   -2.029648e+00 -2.229249e+00   -1.984504e+00 -1.454443e+00
# 25%   -6.893853e-01 -7.259631e-01   -6.919555e-01 -6.671955e-01
# 50%   -2.150816e-01 -1.046362e-01   -2.359800e-01 -2.951869e-01
# 75%    4.693926e-01  5.841756e-01    4.996769e-01  3.635073e-01
# max    3.971288e+00  4.651889e+00    3.976130e+00  5.250529e+00
#
#        smoothness_mean  compactness_mean  concavity_mean   points_mean  \
# count     5.690000e+02      5.690000e+02    5.690000e+02  5.690000e+02
# mean      1.660457e-16      1.882891e-16    5.112099e-17 -4.760886e-17
# std       1.000880e+00      1.000880e+00    1.000880e+00  1.000880e+00
# min      -3.112085e+00     -1.610136e+00   -1.114873e+00 -1.261820e+00
# ...

# %% [markdown]
# if you clearly see we got same (or) equal std (standard deviation) for all of the columns 1.000880e+00

# %%
Xscaled_df = pd.DataFrame(XScaled)

# %%
Xscaled_df.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.513297     -1.605595       -0.540376  -0.542624         0.458285
# 1    -1.001801     -0.079038       -0.934566  -0.877375         0.036986
# 2    -0.876835     -0.572377       -0.867014  -0.801153         0.806996
# 3    -0.808671     -1.372888       -0.781338  -0.768161         1.426135
# 4     0.301824     -1.414775        0.234000   0.161860        -1.190618
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0         -0.654413       -0.614306    -0.307442       0.538081
# 1          0.196319       -0.312987    -0.580343       0.402996
# 2         -0.498443       -0.732448    -0.622129      -0.356400
# 3          0.175472       -0.532950    -0.024740      -0.148296
# 4         -0.663320       -0.688883    -0.576473      -0.330843
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        12.32         12.39           78.85      464.1
# 1         B        10.60         18.95           69.28      346.4
# 2         B        11.04         16.83           70.92      373.2
# 3         B        11.28         13.39           73.00      384.8
# 4         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1959  ...         13.50          15.64            86.97
# ...

# %% [markdown]
# if you compare both of the df &  Xscalead_df you will see in Xscalead_df values are similar to each other where in df values are far from each

# %% [markdown]
# # Building KNN Model

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(Xscaled_df,y,test_size = 0.3,random_state=1)

# %%
X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 249    -0.604181      2.080480       -0.626051  -0.604056        -0.853294
# 58      2.874993      0.211845        3.057588   3.145893         3.440117
# 476    -0.589980      0.798266       -0.544495  -0.588983        -1.922199
# 529    -1.266502     -0.276839       -1.273149  -1.048305        -0.942962
# 422    -0.845593     -1.445027       -0.869073  -0.776409         0.083955
# ..           ...           ...             ...        ...              ...
# 129     0.040531      0.758706        0.074182  -0.071356         0.529451
# 144     0.128576      0.521345        0.224115  -0.028694         0.643316
# 72     -1.444295     -0.090674       -1.313928  -1.167189         0.236249
# 235    -0.695066     -0.725963       -0.678775  -0.666627         1.169940
# 37     -0.632582     -1.079677       -0.570856  -0.631644         1.340737
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
y_train
# Out:
# 249    B
# 58     M
# 476    B
# 529    B
# 422    B
#       ..
# 129    M
# 144    M
# 72     B
# 235    B
# 37     B
# Name: diagnosis, Length: 398, dtype: category
# Categories (2, object): ['B', 'M']

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5,weights='distance')        # here 5 is our k value

# %% [markdown]
# 'uniform' : uniform weights. All points in each neighborhood are weighted equally.

# %% [markdown]
# 'distance' : weight points by the inverse of their distance. in this case, closer neighbors of a query point will have a greater influence than neighbour

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(weights='distance')

# %%
knn.predictions  =  knn.predict(X_test)

# %%
knn.predictions
# Out:
# array(['M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M'], dtype=object)

# %%
knn.score(X_train,y_train)
# Out:
# 1.0

# %%
knn.score(X_test,y_test)
# Out:
# 0.9649122807017544

# %%
from sklearn import metrics

print('Confusion Matrix')

cm = metrics.confusion_matrix(y_test,knn.predictions,labels=['M','B'])

df_cm = pd.DataFrame(cm, index =[ i for i in ['M','B']], columns = [i for i in ['predict M','predict B']])

sns.heatmap(df_cm,annot=True)
plt.show()
# Out:
# Confusion Matrix

# %% [markdown]
# Here only 4 in M  & 2 in B are wrongly predicted     so our knn.score(X_test,y_test) is0.9649122807017544

# %%
df_cm.style.applymap(lambda x: 'color: purple'
                              if (x>0.74 or x<-0.74) and x!=1 
                              else 'color: white')                   # use this as seaborn's heatmap alternative
# Out:
# <style type="text/css">
# #T_d01c5_row0_col0, #T_d01c5_row0_col1, #T_d01c5_row1_col0, #T_d01c5_row1_col1 {
#   color: purple;
# }
# </style>
# <table id="T_d01c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d01c5_level0_col0" class="col_heading level0 col0" >predict M</th>
#       <th id="T_d01c5_level0_col1" class="col_heading level0 col1" >predict B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d01c5_level0_row0" class="row_heading level0 row0" >M</th>
#       <td id="T_d01c5_row0_col0" class="data row0 col0" >53</td>
#       <td id="T_d01c5_row0_col1" class="data row0 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d01c5_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_d01c5_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d01c5_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_cm.style.applymap(lambda x:'color:violet')         # .style.applymap(lambda x:'color:red') is heatmap alternative
# Out:
# <style type="text/css">
# #T_d525f_row0_col0, #T_d525f_row0_col1, #T_d525f_row1_col0, #T_d525f_row1_col1 {
#   color: violet;
# }
# </style>
# <table id="T_d525f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d525f_level0_col0" class="col_heading level0 col0" >predict M</th>
#       <th id="T_d525f_level0_col1" class="col_heading level0 col1" >predict B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d525f_level0_row0" class="row_heading level0 row0" >M</th>
#       <td id="T_d525f_row0_col0" class="data row0 col0" >53</td>
#       <td id="T_d525f_row0_col1" class="data row0 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d525f_level0_row1" class="row_heading level0 row1" >B</th>
#       <td id="T_d525f_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_d525f_row1_col1" class="data row1 col1" >112</td>
#     </tr>
#   </tbody>
# </table>

# %%
len(y_test)      # 171 = M(53+4)  +  B(2+112)
# Out:
# 171

# %% [markdown]
# ##### Above we choose k=5 randomly for your conceptual understanding now let us choose it in right path

# %% [markdown]
# # Choosing K

# %%
from sklearn.model_selection import cross_val_score

score1 = []

for i in range (1,50):
    knn2 = KNeighborsClassifier(n_neighbors= i)
    score2 = cross_val_score(knn2,XScaled,y,cv=10)
    score1.append(score2.mean())
# Out:
# C:\Users\TURBO2\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# above cv=10 means, iterating 10 times & stored in score 2

# %%
score2
# Out:
# array([0.96491228, 0.94736842, 0.94736842, 0.92982456, 0.96491228,
#        0.98245614, 0.92982456, 0.94736842, 0.94736842, 0.96428571])

# %%
score1
# Out:
# [0.9490914786967419,
#  0.9560776942355889,
#  0.9666040100250626,
#  0.9648809523809525,
#  0.9683897243107771,
#  0.9631265664160402,
#  0.9683897243107771,
#  0.9666353383458647,
#  0.9701441102756894,
#  0.9648809523809524,
#  0.9683897243107771,
#  0.9683897243107771,
#  0.9666040100250626,
#  0.9613721804511279,
#  0.9648809523809524,
#  0.9595864661654134,
#  0.9613721804511279,
#  0.9613721804511279,
#  0.9596177944862155,
#  0.9596177944862155,
#  0.9578634085213034,
#  0.9561090225563911,
#  0.9596177944862155,
#  0.956077694235589,
#  0.956077694235589,
#  0.9543233082706767,
#  0.9578634085213034,
#  0.9543233082706767,
#  0.9560776942355889,
#  0.9560776942355889,
#  0.9560776942355889,
#  0.9543233082706767,
#  0.9560776942355889,
#  0.9543233082706767,
#  0.956077694235589,
#  0.9578320802005011,
#  0.956077694235589,
#  0.9543233082706767,
#  0.956077694235589,
#  0.956077694235589,
#  0.956077694235589,
#  0.956077694235589,
#  0.956077694235589,
# ...

# %%
len(score1)
# Out:
# 49

# %%
plt.figure(figsize=(20,10))

plt.plot(range(1,50),score1,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)

plt.title('Accuracy Rate vs K-Vatues')
plt.xlabel('K')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ##### it clearly proven thet if our k value increases than predicting y chances dicreses , see @ 9 as K we have upto 97% of chance in predicting y

# %% [markdown]
# Note: Choosing the K to be an odd number is a good practice in order to avaoid tie.
#
#  Choosing K to be 10and 50 in this exercise is just for understanding.
#  In practice, choose K to be an odd number.

# %%
# now i know where is my K value is high so let me start the action again

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=9, weights='distance')        # here 5 is our k value

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9, weights='distance')

# %%
knn.predictions  =  knn.predict(X_test)

# %%
knn.predictions
# Out:
# array(['M', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'B', 'B', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'B', 'B', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B',
#        'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'B', 'B', 'B', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M',
#        'M', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'B', 'M', 'M', 'M',
#        'B', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'B', 'M', 'M', 'B',
#        'B', 'M', 'B', 'M', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'B', 'B',
#        'M', 'B', 'B', 'B', 'M', 'B', 'B', 'B', 'M', 'M', 'M', 'B', 'B',
#        'B', 'B', 'M', 'M', 'B', 'B', 'B', 'M', 'B', 'B', 'M', 'M', 'M',
#        'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'B', 'M', 'B', 'M',
#        'M', 'B', 'B', 'B', 'B', 'M', 'B', 'M', 'M', 'B', 'B', 'M', 'B',
#        'B', 'M'], dtype=object)

# %%
knn.score(X_train,y_train)
# Out:
# 1.0

# %%
knn.score(X_test,y_test)
# Out:
# 0.9766081871345029

# %%
from sklearn import metrics

print('Confusion Matrix')

cm = metrics.confusion_matrix(y_test,knn.predictions,labels=['M','B'])

df_cm = pd.DataFrame(cm, index =[ i for i in ['M','B']], columns = [i for i in ['predict M','predict B']])

sns.heatmap(df_cm,annot=True)
plt.show()
# Out:
# Confusion Matrix

# %% [markdown]
# accuracy = 0.9649122807017544 when k =5    &    accuaracy = 0.9766081871345029    when   k= 9
